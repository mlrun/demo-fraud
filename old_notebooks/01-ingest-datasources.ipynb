# %% [markdown]
# # Part 1: Data ingestion

# %% [markdown]
# ```
# This demo works with the online feature store, which is currently not part of the Open Source default deployment.
# ```
# This demo showcases financial fraud prevention using the MLRun feature store to define complex features that help identify
# fraud. Fraud prevention specifically is a challenge because it requires processing raw transaction and events in real-time, and
# being able to quickly respond and block transactions before they occur.
#
# To address this, you create a development pipeline and a production pipeline. Both pipelines share the same feature
# engineering and model code, but serve data very differently. Furthermore, you automate the data and model monitoring
# process, identify drift and trigger retraining in a CI/CD pipeline. This process is described in the diagram below:
#
# ![Feature store demo diagram - fraud prevention](images/feature_store_demo_diagram.png)
#
# By the end of this tutorial you’ll learn how to:
#
# - Create an ingestion pipeline for each data source.
# - Define preprocessing, aggregation and validation of the pipeline.
# - Run the pipeline locally within the notebook.
# - Launch a real-time function to ingest live data.
# - Schedule a cron to run the task when needed.

# %% [markdown]
# The raw data is described as follows:
#
# | TRANSACTIONS                                                                    || &#x2551; |USER EVENTS                                                                           ||
# |-----------------|----------------------------------------------------------------|----------|-----------------|----------------------------------------------------------------|
# | **age**         | age group value 0-6. Some values are marked as U for unknown   | &#x2551; | **source**      | The party/entity related to the event                          |
# | **gender**      | A character to define the gender                               | &#x2551; | **event**       | event, such as login or password change                        |
# | **zipcodeOri**  | ZIP code of the person originating the transaction             | &#x2551; | **timestamp**   | The date and time of the event                                 |
# | **zipMerchant** | ZIP code of the merchant receiving the transaction             | &#x2551; |                 |                                                                |
# | **category**    | category of the transaction (e.g., transportation, food, etc.) | &#x2551; |                 |                                                                |
# | **amount**      | the total amount of the transaction                            | &#x2551; |                 |                                                                |
# | **fraud**       | whether the transaction is fraudulent                          | &#x2551; |                 |                                                                |
# | **timestamp**   | the date and time in which the transaction took place          | &#x2551; |                 |                                                                |
# | **source**      | the ID of the party/entity performing the transaction          | &#x2551; |                 |                                                                |
# | **target**      | the ID of the party/entity receiving the transaction           | &#x2551; |                 |                                                                |
# | **device**      | the device ID used to perform the transaction                  | &#x2551; |                 |                                                                |

# %% [markdown]
# This notebook introduces how to **Ingest** different data sources to the **Feature Store**.
#
# The following FeatureSets are created:
# - **Transactions**: Monetary transactions between a source and a target.
# - **Events**: Account events such as account login or a password change.
# - **Label**: Fraud label for the data.

# %%
# !/User/align_mlrun.sh
# Out:
# Server 1.4.0-rc7 & client 1.3.0 are unaligned.
# Updating client...
# Found existing installation: mlrun 1.3.0
# Uninstalling mlrun-1.3.0:
#   Successfully uninstalled mlrun-1.3.0
# Collecting mlrun[complete]==1.4.0-rc7
#   Downloading mlrun-1.4.0rc7-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.8 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: python-dotenv~=0.17.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.17.1)
# Requirement already satisfied: deprecated~=1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.2.13)
# Requirement already satisfied: deepdiff~=5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (5.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.26.15)
# Requirement already satisfied: click~=8.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (8.0.4)
# Requirement already satisfied: setuptools~=65.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (65.6.3)
# Requirement already satisfied: aiohttp-retry~=2.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2.8.3)
# Requirement already satisfied: tabulate~=0.8.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.8.10)
# Requirement already satisfied: sqlalchemy~=1.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.4.47)
# Requirement already satisfied: GitPython>=3.1.30,~=3.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.1.31)
# Requirement already satisfied: requests~=2.22 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2.28.2)
# Requirement already satisfied: ipython<9.0,>=7.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (8.11.0)
# Requirement already satisfied: pyarrow<12,>=10.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (10.0.1)
# Requirement already satisfied: dask~=2021.11.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2021.11.2)
# Requirement already satisfied: v3iofs~=0.1.15 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.1.15)
# Requirement already satisfied: protobuf<3.20,>=3.13 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.19.6)
# Requirement already satisfied: kubernetes~=12.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (12.0.1)
# Requirement already satisfied: kfp<1.8.14,~=1.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.8.13)
# Collecting nuclio-jupyter~=0.9.10
#   Using cached nuclio_jupyter-0.9.10-py3-none-any.whl (51 kB)
# Requirement already satisfied: v3io-frames~=0.10.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.10.5)
# Requirement already satisfied: mergedeep~=1.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.3.4)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.22.4)
# Requirement already satisfied: fastapi~=0.92.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.92.0)
# Requirement already satisfied: v3io~=0.5.20 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.5.20)
# Requirement already satisfied: orjson<3.8.12,~=3.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.8.10)
# Requirement already satisfied: pandas<1.5.0,~=1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.4.4)
# Requirement already satisfied: aiohttp~=3.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.8.4)
# Requirement already satisfied: nest-asyncio~=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.5.6)
# Requirement already satisfied: distributed~=2021.11.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2021.11.2)
# Requirement already satisfied: pyyaml~=5.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (5.4.1)
# Requirement already satisfied: humanfriendly~=8.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (8.2)
# Requirement already satisfied: semver~=2.13 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2.13.0)
# Requirement already satisfied: chardet<4.0,>=3.0.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.0.4)
# Requirement already satisfied: alembic~=1.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.10.3)
# Collecting fsspec~=2023.1.0
#   Using cached fsspec-2023.1.0-py3-none-any.whl (143 kB)
# Requirement already satisfied: inflection~=0.5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.5.1)
# Collecting storey~=1.4.0
#   Downloading storey-1.4.3-py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: pymysql~=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.0.2)
# Requirement already satisfied: pydantic~=1.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.10.7)
# Requirement already satisfied: redis~=4.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (4.5.4)
# Requirement already satisfied: azure-core~=1.24 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.26.4)
# Collecting s3fs~=2023.1.0
#   Downloading s3fs-2023.1.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: azure-identity~=1.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (1.12.0)
# Requirement already satisfied: kafka-python~=2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (2.0.2)
# Requirement already satisfied: google-cloud-bigquery[bqstorage,pandas]~=3.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (3.10.0)
# Collecting boto3~=1.24.59
#   Downloading boto3-1.24.96-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 6.6 MB/s eta 0:00:00
# Collecting aiobotocore~=2.4.2
#   Downloading aiobotocore-2.4.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: msrest~=0.6.21 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.6.21)
# Requirement already satisfied: azure-keyvault-secrets~=4.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (4.7.0)
# Collecting gcsfs~=2023.1.0
#   Downloading gcsfs-2023.1.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: graphviz~=0.20.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (0.20)
# Collecting avro~=1.11
#   Downloading avro-1.11.1.tar.gz (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: azure-storage-blob~=12.13 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (12.16.0)
# Requirement already satisfied: plotly<5.12.0,~=5.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (5.11.0)
# Collecting adlfs~=2022.2.0
#   Downloading adlfs-2022.2.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyopenssl>=23 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun[complete]==1.4.0-rc7) (23.1.1)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.46 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from adlfs~=2022.2.0->mlrun[complete]==1.4.0-rc7) (0.0.52)
# Requirement already satisfied: wrapt>=1.10.10 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiobotocore~=2.4.2->mlrun[complete]==1.4.0-rc7) (1.15.0)
# Requirement already satisfied: aioitertools>=0.5.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiobotocore~=2.4.2->mlrun[complete]==1.4.0-rc7) (0.11.0)
# Collecting botocore<1.27.60,>=1.27.59
#   Downloading botocore-1.27.59-py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 20.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: yarl<2.0,>=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (3.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun[complete]==1.4.0-rc7) (22.2.0)
# Requirement already satisfied: Mako in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from alembic~=1.9->mlrun[complete]==1.4.0-rc7) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from alembic~=1.9->mlrun[complete]==1.4.0-rc7) (4.5.0)
# Requirement already satisfied: six>=1.11.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-core~=1.24->mlrun[complete]==1.4.0-rc7) (1.16.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-identity~=1.5->mlrun[complete]==1.4.0-rc7) (1.0.0)
# Requirement already satisfied: msal<2.0.0,>=1.12.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-identity~=1.5->mlrun[complete]==1.4.0-rc7) (1.22.0)
# Requirement already satisfied: cryptography>=2.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-identity~=1.5->mlrun[complete]==1.4.0-rc7) (40.0.2)
# Requirement already satisfied: azure-common~=1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-keyvault-secrets~=4.2->mlrun[complete]==1.4.0-rc7) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-keyvault-secrets~=4.2->mlrun[complete]==1.4.0-rc7) (0.6.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from boto3~=1.24.59->mlrun[complete]==1.4.0-rc7) (0.10.0)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.5 MB/s eta 0:00:00
# Collecting boto3~=1.24.59
#   Downloading boto3-1.24.95-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 1.7 MB/s eta 0:00:00a 0:00:01
#   Downloading boto3-1.24.94-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.8 MB/s eta 0:00:00
#   Downloading boto3-1.24.93-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 7.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.92-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.7 MB/s eta 0:00:00
#   Downloading boto3-1.24.91-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 15.1 MB/s eta 0:00:00
#   Downloading boto3-1.24.90-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.7 MB/s eta 0:00:00
#   Downloading boto3-1.24.89-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.3 MB/s eta 0:00:00
#   Downloading boto3-1.24.88-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 4.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.87-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 12.0 MB/s eta 0:00:00
#   Downloading boto3-1.24.86-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 7.8 MB/s eta 0:00:00
#   Downloading boto3-1.24.85-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 12.9 MB/s eta 0:00:00
#   Downloading boto3-1.24.84-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 11.3 MB/s eta 0:00:00
#   Downloading boto3-1.24.83-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 7.7 MB/s eta 0:00:00
#   Downloading boto3-1.24.82-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Downloading boto3-1.24.81-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.80-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.4 MB/s eta 0:00:00
#   Downloading boto3-1.24.79-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 15.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.78-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.8 MB/s eta 0:00:00
#   Downloading boto3-1.24.77-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.2 MB/s eta 0:00:00
#   Downloading boto3-1.24.76-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.8 MB/s eta 0:00:00
#   Downloading boto3-1.24.75-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.5 MB/s eta 0:00:00
#   Downloading boto3-1.24.74-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.2 MB/s eta 0:00:00
#   Downloading boto3-1.24.73-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.3 MB/s eta 0:00:00
#   Downloading boto3-1.24.72-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.4 MB/s eta 0:00:00
#   Downloading boto3-1.24.71-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 11.9 MB/s eta 0:00:00
#   Downloading boto3-1.24.70-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 14.9 MB/s eta 0:00:00
#   Downloading boto3-1.24.69-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.5 MB/s eta 0:00:00
#   Downloading boto3-1.24.68-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 9.3 MB/s eta 0:00:00
#   Downloading boto3-1.24.67-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 13.7 MB/s eta 0:00:00
#   Downloading boto3-1.24.66-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 12.4 MB/s eta 0:00:00
#   Downloading boto3-1.24.65-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 10.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.64-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 19.3 MB/s eta 0:00:00
#   Downloading boto3-1.24.63-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 21.6 MB/s eta 0:00:00
#   Downloading boto3-1.24.62-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 22.8 MB/s eta 0:00:00
#   Downloading boto3-1.24.61-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 20.0 MB/s eta 0:00:00
#   Downloading boto3-1.24.60-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 19.0 MB/s eta 0:00:00
#   Downloading boto3-1.24.59-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (2.2.1)
# Requirement already satisfied: toolz>=0.8.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (1.4.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from deepdiff~=5.0->mlrun[complete]==1.4.0-rc7) (4.1.0)
# Requirement already satisfied: msgpack>=0.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (1.0.5)
# Requirement already satisfied: psutil>=5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (5.9.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (3.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (1.7.0)
# Requirement already satisfied: tornado>=6.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (6.3)
# Requirement already satisfied: jinja2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun[complete]==1.4.0-rc7) (3.1.2)
# Requirement already satisfied: starlette<0.26.0,>=0.25.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from fastapi~=0.92.0->mlrun[complete]==1.4.0-rc7) (0.25.0)
# Requirement already satisfied: google-auth-oauthlib in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (0.4.6)
# Requirement already satisfied: decorator>4.1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (5.1.1)
# Requirement already satisfied: google-auth>=1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (1.35.0)
# Requirement already satisfied: google-cloud-storage in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (1.44.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from GitPython>=3.1.30,~=3.1->mlrun[complete]==1.4.0-rc7) (4.0.10)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (2.10.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.15.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (1.22.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (2.3.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (1.48.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (2.8.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (2.4.1)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0.0dev,>=2.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (2.16.2)
# Requirement already satisfied: db-dtypes<2.0.0dev,>=0.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (1.1.1)
# Requirement already satisfied: stack-data in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.6.2)
# Requirement already satisfied: matplotlib-inline in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (5.9.0)
# Requirement already satisfied: backcall in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (3.0.38)
# Requirement already satisfied: pickleshare in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.17.2)
# Requirement already satisfied: absl-py<2,>=0.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (1.4.0)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.10.1)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.7.0)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.15)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.1.10)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (1.8.5)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (1.12.11)
# Requirement already satisfied: fire<1,>=0.3.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.5.0)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (3.0.1)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (3.2.0)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.14 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.1.16)
# Requirement already satisfied: certifi>=14.05.14 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun[complete]==1.4.0-rc7) (2022.12.7)
# Requirement already satisfied: requests-oauthlib in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun[complete]==1.4.0-rc7) (1.3.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun[complete]==1.4.0-rc7) (1.5.1)
# Requirement already satisfied: nbconvert>=6.4.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (7.3.1)
# Requirement already satisfied: notebook>=6.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (6.5.4)
# Requirement already satisfied: pytz>=2020.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pandas<1.5.0,~=1.2->mlrun[complete]==1.4.0-rc7) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from plotly<5.12.0,~=5.4->mlrun[complete]==1.4.0-rc7) (8.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from requests~=2.22->mlrun[complete]==1.4.0-rc7) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from sqlalchemy~=1.4->mlrun[complete]==1.4.0-rc7) (2.0.2)
# Requirement already satisfied: xxhash>=1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from storey~=1.4.0->mlrun[complete]==1.4.0-rc7) (3.2.0)
# Requirement already satisfied: ujson>=3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io~=0.5.20->mlrun[complete]==1.4.0-rc7) (5.7.0)
# Requirement already satisfied: future>=0.18.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io~=0.5.20->mlrun[complete]==1.4.0-rc7) (0.18.3)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io-frames~=0.10.4->mlrun[complete]==1.4.0-rc7) (1.59.0)
# Requirement already satisfied: grpcio-tools!=1.34.0,<1.49,>=1.30 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io-frames~=0.10.4->mlrun[complete]==1.4.0-rc7) (1.48.2)
# Requirement already satisfied: adal>=0.4.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-datalake-store<0.1,>=0.0.46->adlfs~=2022.2.0->mlrun[complete]==1.4.0-rc7) (1.2.7)
# Requirement already satisfied: cffi in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from azure-datalake-store<0.1,>=0.0.46->adlfs~=2022.2.0->mlrun[complete]==1.4.0-rc7) (1.15.1)
# Requirement already satisfied: termcolor in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from fire<1,>=0.3.1->kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (2.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.30,~=3.1->mlrun[complete]==1.4.0-rc7) (5.0.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (1.48.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-api-python-client<2,>=1.7.8->kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-api-python-client<2,>=1.7.8->kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.1.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery[bqstorage,pandas]~=3.2->mlrun[complete]==1.4.0-rc7) (1.5.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from jedi>=0.16->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jsonschema<4,>=3.0.1->kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.19.3)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from msal<2.0.0,>=1.12.0->azure-identity~=1.5->mlrun[complete]==1.4.0-rc7) (2.6.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity~=1.5->mlrun[complete]==1.4.0-rc7) (2.7.0)
# Requirement already satisfied: defusedxml in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.7.3)
# Requirement already satisfied: jupyter-core>=4.7 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (5.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.1.2)
# Requirement already satisfied: nbformat>=5.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (5.8.0)
# Requirement already satisfied: tinycss2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (4.12.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.0.5)
# Requirement already satisfied: bleach in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.2.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (6.5.0)
# Requirement already satisfied: pyzmq>=17 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (25.0.2)
# Requirement already satisfied: argon2-cffi in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (8.2.0)
# Requirement already satisfied: ipython-genutils in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.5.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (1.8.0)
# Requirement already satisfied: ipykernel in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (5.5.5)
# Requirement already satisfied: prometheus-client in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from packaging>=20.0->dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (3.0.9)
# Requirement already satisfied: locket in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from partd>=0.3.10->dask~=2021.11.2->mlrun[complete]==1.4.0-rc7) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pexpect>4.3->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.7.0)
# Requirement already satisfied: wcwidth in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.2.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from requests-oauthlib->kubernetes~=12.0->mlrun[complete]==1.4.0-rc7) (3.2.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from starlette<0.26.0,>=0.25.0->fastapi~=0.92.0->mlrun[complete]==1.4.0-rc7) (3.6.2)
# Requirement already satisfied: wheel in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from strip-hints<1,>=0.1.8->kfp<1.8.14,~=1.8.0->mlrun[complete]==1.4.0-rc7) (0.38.4)
# Requirement already satisfied: pure-eval in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython<9.0,>=7.0->mlrun[complete]==1.4.0-rc7) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.26.0,>=0.25.0->fastapi~=0.92.0->mlrun[complete]==1.4.0-rc7) (1.3.0)
# Requirement already satisfied: pycparser in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from cffi->azure-datalake-store<0.1,>=0.0.46->adlfs~=2022.2.0->mlrun[complete]==1.4.0-rc7) (2.21)
# Requirement already satisfied: zipp>=0.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-core>=4.7->nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (3.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.2.2)
# Requirement already satisfied: fastjsonschema in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.16.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs~=2023.1.0->mlrun[complete]==1.4.0-rc7) (0.4.8)
# Requirement already satisfied: argon2-cffi-bindings in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from argon2-cffi->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.4.1)
# Requirement already satisfied: webencodings in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from bleach->nbconvert>=6.4.5->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.5.1)
# Requirement already satisfied: jupyter-server-terminals in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.10->mlrun[complete]==1.4.0-rc7) (0.1.4)
# WARNING: jsonschema 3.2.0 does not provide the extra 'format-nongpl'
# Building wheels for collected packages: adlfs, avro
#   Building wheel for adlfs (setup.py) ... done
#   Created wheel for adlfs: filename=adlfs-2022.2.0-py3-none-any.whl size=22083 sha256=8923d8448e0771a58547d7d6d74e117d9f8294d97d2632eda8038e7296093164
#   Stored in directory: /igz/.cache/pip/wheels/d7/f6/fe/1d8d9054afbb677981f820cd86dc19f1736199848fbff845be
#   Building wheel for avro (pyproject.toml) ... done
#   Created wheel for avro: filename=avro-1.11.1-py2.py3-none-any.whl size=116718 sha256=ace7ed8fef5aa42bda8d3e9ed11c6497746da4d36cfcfb7fe8c3607714deeb89
#   Stored in directory: /igz/.cache/pip/wheels/1f/5c/64/f462a1ff9837cd27218d4a0b71dff7692f221981273dd95f8d
# Successfully built adlfs avro
# Installing collected packages: fsspec, avro, botocore, s3transfer, aiobotocore, storey, s3fs, boto3, gcsfs, adlfs, nuclio-jupyter, mlrun
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.8.1
#     Uninstalling fsspec-2021.8.1:
#       Successfully uninstalled fsspec-2021.8.1
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.20.106
#     Uninstalling botocore-1.20.106:
#       Successfully uninstalled botocore-1.20.106
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.4.2
#     Uninstalling s3transfer-0.4.2:
#       Successfully uninstalled s3transfer-0.4.2
#   Attempting uninstall: aiobotocore
#     Found existing installation: aiobotocore 1.4.2
#     Uninstalling aiobotocore-1.4.2:
#       Successfully uninstalled aiobotocore-1.4.2
#   Attempting uninstall: storey
#     Found existing installation: storey 1.3.17
#     Uninstalling storey-1.3.17:
#       Successfully uninstalled storey-1.3.17
#   Attempting uninstall: s3fs
#     Found existing installation: s3fs 2021.8.1
#     Uninstalling s3fs-2021.8.1:
#       Successfully uninstalled s3fs-2021.8.1
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.17.106
#     Uninstalling boto3-1.17.106:
#       Successfully uninstalled boto3-1.17.106
#   Attempting uninstall: gcsfs
#     Found existing installation: gcsfs 2021.8.1
#     Uninstalling gcsfs-2021.8.1:
#       Successfully uninstalled gcsfs-2021.8.1
#   Attempting uninstall: adlfs
#     Found existing installation: adlfs 2021.8.2
#     Uninstalling adlfs-2021.8.2:
#       Successfully uninstalled adlfs-2021.8.2
#   Attempting uninstall: nuclio-jupyter
#     Found existing installation: nuclio-jupyter 0.9.9
#     Uninstalling nuclio-jupyter-0.9.9:
#       Successfully uninstalled nuclio-jupyter-0.9.9
# Successfully installed adlfs-2022.2.0 aiobotocore-2.4.2 avro-1.11.1 boto3-1.24.59 botocore-1.27.59 fsspec-2023.1.0 gcsfs-2023.1.0 mlrun-1.4.0rc7 nuclio-jupyter-0.9.10 s3fs-2023.1.0 s3transfer-0.6.1 storey-1.4.3

# %%
project_name = 'fraud-demo'

# %%
import mlrun

# Initialize the MLRun project object
project = mlrun.get_or_create_project(project_name, context="./", user_project=True)
# Out:
# > 2023-06-20 14:47:37,215 [info] loaded project fraud-demo from MLRun DB

# %% [markdown]
# ## Step 1 - Define and test the feature engineering pipelines

# %% [markdown]
# ## 1.1 - Transactions

# %% [markdown]
# ### Transactions

# %%
import pandas as pd
from src.date_adjust import adjust_data_timespan

# Fetch the transactions dataset from the server
transactions_data = pd.read_csv('https://s3.wasabisys.com/iguazio/data/fraud-demo-mlrun-fs-docs/data.csv', parse_dates=['timestamp'])

# use only first 10k
transactions_data = transactions_data.sort_values(by='source', axis=0)[:10000]

# Adjust the samples timestamp for the past 2 days
transactions_data = adjust_data_timespan(transactions_data, new_period='2d')

# Sorting after adjusting timestamps
transactions_data = transactions_data.sort_values(by='timestamp', axis=0)

# Preview
transactions_data.head(3)
# Out:
#         step age gender  zipcodeOri  zipMerchant           category  amount  \
# 274633    91   5      F       28007        28007  es_transportation   26.92
# 286902    94   2      M       28007        28007  es_transportation   48.22
# 416998   131   3      M       28007        28007  es_transportation   17.56
#
#         fraud                     timestamp       source       target  \
# 274633      0 2023-06-18 14:47:58.790059000  C1022153336  M1823072687
# 286902      0 2023-06-18 14:48:17.083684913  C1006176917   M348934600
# 416998      0 2023-06-18 14:48:22.190854939  C1010936270   M348934600
#
#                                   device
# 274633  33832bb8607545df97632a7ab02d69c4
# 286902  fadd829c49e74ffa86c8da3be75ada53
# 416998  58d0422a50bc40c89d2b4977b2f1beea

# %% [markdown]
# ### Transactions - create a feature set and preprocessing pipeline
# Create the feature set (data pipeline) definition for the **credit transaction processing** that describes the
# offline/online data transformations and aggregations.<br>
# The feature store automatically adds an offline `parquet` target and an online `NoSQL` target by using `set_targets()`.
#
# The data pipeline consists of:
#
# * **Extracting** the data components (hour, day of week)
# * **Mapping** the age values
# * **One hot encoding** for the transaction category and the gender
# * **Aggregating** the amount (avg, sum, count, max over 2/12/24 hour time windows)
# * **Aggregating** the transactions per category (over 14 days time windows)
# * **Writing** the results to **offline** (Parquet) and **online** (NoSQL) targets

# %%
# Import MLRun's Feature Store
import mlrun.feature_store as fstore
from mlrun.feature_store.steps import OneHotEncoder, MapValues, DateExtractor

# %%
# Define the transactions FeatureSet
transaction_set = fstore.FeatureSet("transactions", 
                                 entities=[fstore.Entity("source")], 
                                 timestamp_key='timestamp', 
                                 description="transactions feature set")

# %%
# Define and add value mapping
main_categories = ["es_transportation", "es_health", "es_otherservices",
       "es_food", "es_hotelservices", "es_barsandrestaurants",
       "es_tech", "es_sportsandtoys", "es_wellnessandbeauty",
       "es_hyper", "es_fashion", "es_home", "es_contents",
       "es_travel", "es_leisure"]

# One Hot Encode the newly defined mappings
one_hot_encoder_mapping = {'category': main_categories,
                           'gender': list(transactions_data.gender.unique())}

# Define the graph steps
transaction_set.graph\
    .to(DateExtractor(parts = ['hour', 'day_of_week'], timestamp_col = 'timestamp'))\
    .to(MapValues(mapping={'age': {'U': '0'}}, with_original_features=True))\
    .to(OneHotEncoder(mapping=one_hot_encoder_mapping))


# Add aggregations for 2, 12, and 24 hour time windows
transaction_set.add_aggregation(name='amount',
                                column='amount',
                                operations=['avg','sum', 'count','max'],
                                windows=['2h', '12h', '24h'],
                                period='1h')


# Add the category aggregations over a 14 day window
for category in main_categories:
    transaction_set.add_aggregation(name=category,column=f'category_{category}',
                                    operations=['sum'], windows=['14d'], period='1d')

# Add default (offline-parquet & online-nosql) targets
transaction_set.set_targets()

# Plot the pipeline so you can see the different steps
transaction_set.plot(rankdir="LR", with_targets=True)

# %% [markdown]
# ### Transactions - preview

# %%
fstore.preview(transaction_set, transactions_data,)
# Out:
#              amount_sum_2h  amount_sum_12h  amount_sum_24h  amount_count_2h  \
# source
# C1022153336          26.92           26.92           26.92              1.0
# C1006176917          48.22           48.22           48.22              1.0
# C1010936270          17.56           17.56           17.56              1.0
# C1033736586           4.50            4.50            4.50              1.0
# C1019071188           1.83            1.83            1.83              1.0
# ...                    ...             ...             ...              ...
# C1032715879         118.62          805.10         1730.23              4.0
# C1005806982          31.14          150.64          330.61              1.0
# C1018783569         397.43         1076.37         1968.00              6.0
# C1014847580         118.22          935.26         2082.60              5.0
# C1023803355         237.95         1259.07         2451.98              5.0
#
#              amount_count_12h  amount_count_24h  amount_max_2h  \
# source
# C1022153336               1.0               1.0          26.92
# C1006176917               1.0               1.0          48.22
# C1010936270               1.0               1.0          17.56
# C1033736586               1.0               1.0           4.50
# C1019071188               1.0               1.0           1.83
# ...                       ...               ...            ...
# C1032715879              27.0              58.0          54.55
# C1005806982               2.0               5.0          31.14
# C1018783569              25.0              59.0         218.48
# C1014847580              31.0              69.0          34.93
# C1023803355              37.0              72.0          77.76
#
#              amount_max_12h  amount_max_24h  amount_avg_2h  ...  \
# source                                                      ...
# C1022153336           26.92           26.92      26.920000  ...
# C1006176917           48.22           48.22      48.220000  ...
# C1010936270           17.56           17.56      17.560000  ...
# C1033736586            4.50            4.50       4.500000  ...
# C1019071188            1.83            1.83       1.830000  ...
# ...                     ...             ...            ...  ...
# C1032715879           70.47           85.97      29.655000  ...
# C1005806982          119.50          119.50      31.140000  ...
# C1018783569          218.48          218.48      66.238333  ...
# C1014847580           79.16           89.85      23.644000  ...
# C1023803355           95.71           95.71      47.590000  ...
#
#              category_es_contents  category_es_travel  category_es_leisure  \
# source
# C1022153336                     0                   0                    0
# C1006176917                     0                   0                    0
# C1010936270                     0                   0                    0
# C1033736586                     0                   0                    0
# C1019071188                     0                   0                    0
# ...                           ...                 ...                  ...
# C1032715879                     0                   0                    0
# C1005806982                     0                   0                    0
# C1018783569                     0                   0                    0
# C1014847580                     0                   0                    0
# C1023803355                     0                   0                    0
#
#              amount  fraud                     timestamp       target  \
# source
# C1022153336   26.92      0 2023-06-18 14:47:58.790059000  M1823072687
# C1006176917   48.22      0 2023-06-18 14:48:17.083684913   M348934600
# C1010936270   17.56      0 2023-06-18 14:48:22.190854939   M348934600
# C1033736586    4.50      0 2023-06-18 14:48:34.483606118  M1823072687
# C1019071188    1.83      0 2023-06-18 14:49:08.372688001   M348934600
# ...             ...    ...                           ...          ...
# C1032715879   26.00      0 2023-06-20 14:46:56.703912884   M348934600
# C1005806982   31.14      0 2023-06-20 14:47:01.067846022  M1741626453
# C1018783569  218.48      0 2023-06-20 14:47:28.450369602  M1053599405
# C1014847580   34.93      0 2023-06-20 14:47:35.432624958  M1823072687
# C1023803355   35.65      0 2023-06-20 14:47:58.790059000   M348934600
#
#                                        device  timestamp_hour  \
# source
# C1022153336  33832bb8607545df97632a7ab02d69c4              14
# C1006176917  fadd829c49e74ffa86c8da3be75ada53              14
# C1010936270  58d0422a50bc40c89d2b4977b2f1beea              14
# C1033736586  30b269ae55984e5584f1dd5f642ac1a3              14
# C1019071188  97bee3503a984f59aa6139b59f933c0b              14
# ...                                       ...             ...
# C1032715879  dcd0943b34254126a2d79d3ac652f268              14
# C1005806982  c186fb979a77422fa06296c3ff2813f6              14
# C1018783569  73bdcf0627aa4cc5b882f397cf0d1177              14
# C1014847580  1b216268a9bd4937912c49d16adb5b67              14
# C1023803355  e2f1b14f73014143a94f7d9505638134              14
#
#              timestamp_day_of_week
# source
# C1022153336                      6
# C1006176917                      6
# C1010936270                      6
# C1033736586                      6
# C1019071188                      6
# ...                            ...
# C1032715879                      1
# C1005806982                      1
# C1018783569                      1
# C1014847580                      1
# C1023803355                      1
#
# [10000 rows x 56 columns]

# %% [markdown]
# After performing the ingestion process, you can see all of the different features that were created with the help of the UI, asshown in the image below.

# %% [markdown]
# ![Features Catalog - fraud prevention](images/features-catalog-transaction.png)

# %% [markdown]
# ## 1.2 - User events

# %% [markdown]
# ### User events - fetching

# %%
# Fetch the user_events dataset from the server
user_events_data = pd.read_csv('https://s3.wasabisys.com/iguazio/data/fraud-demo-mlrun-fs-docs/events.csv', 
                               index_col=0, quotechar="\'", parse_dates=['timestamp'])

# Adjust to the last 2 days to see the latest aggregations in the online feature vectors
user_events_data = adjust_data_timespan(user_events_data, new_period='2d')

# Preview
user_events_data.head(3)
# Out:
#             source            event                     timestamp
# 45553   C137986193  password_change 2023-06-18 14:48:46.595166000
# 24134  C1940951230   details_change 2023-06-18 14:48:47.643348091
# 64444   C247537602            login 2023-06-18 14:48:49.298131103

# %% [markdown]
# ### User events - create a feature set and preprocessing pipeline
#
# Now define the events feature set.
# This is a pretty straightforward pipeline in which you only "one hot encode" the event categories and save the data to the default targets.

# %%
user_events_set = fstore.FeatureSet("events",
                           entities=[fstore.Entity("source")],
                           timestamp_key='timestamp', 
                           description="user events feature set")

# %%
# Define and add value mapping
events_mapping = {'event': list(user_events_data.event.unique())}

# One Hot Encode
user_events_set.graph.to(OneHotEncoder(mapping=events_mapping))

# Add default (offline-parquet & online-nosql) targets
user_events_set.set_targets()

# Plot the pipeline so you can see the different steps
user_events_set.plot(rankdir="LR", with_targets=True)

# %% [markdown]
# ### User Events - preview

# %%
fstore.preview(user_events_set, user_events_data)
# Out:
#              event_password_change  event_details_change  event_login  \
# source
# C137986193                       1                     0            0
# C1940951230                      0                     1            0
# C247537602                       0                     0            1
# C470079617                       1                     0            0
# C1142118359                      0                     0            1
# ...                            ...                   ...          ...
# C71938921                        0                     0            1
# C1790426542                      1                     0            0
# C662187574                       0                     0            1
# C1461183154                      0                     0            1
# C129566217                       0                     0            1
#
#                                 timestamp
# source
# C137986193  2023-06-18 14:48:46.595166000
# C1940951230 2023-06-18 14:48:47.643348091
# C247537602  2023-06-18 14:48:49.298131103
# C470079617  2023-06-18 14:48:50.588580428
# C1142118359 2023-06-18 14:48:51.378872830
# ...                                   ...
# C71938921   2023-06-20 14:48:37.144715776
# C1790426542 2023-06-20 14:48:42.215919974
# C662187574  2023-06-20 14:48:43.636574178
# C1461183154 2023-06-20 14:48:44.334714428
# C129566217  2023-06-20 14:48:46.595166000
#
# [82092 rows x 4 columns]

# %% [markdown]
# ## Step 2 - Create a labels data set for model training

# %% [markdown]
# ### Label set - create a feature set
# This feature set contains the label for the fraud demo. It is ingested directly to the default targets without any changes.

# %%
def create_labels(df):
    labels = df[['fraud','timestamp']].copy()
    labels = labels.rename(columns={"fraud": "label"})
    labels['timestamp'] = labels['timestamp'].astype("datetime64[ms]")
    labels['label'] = labels['label'].astype(int)
    return labels

# %%
from mlrun.datastore import ParquetTarget
import os

# Define the "labels" feature set
labels_set = fstore.FeatureSet("labels", 
                           entities=[fstore.Entity("source")], 
                           timestamp_key='timestamp',
                           description="training labels",
                           engine="pandas")

labels_set.graph.to(name="create_labels", handler=create_labels)


# specify only Parquet (offline) target since its not used for real-time
target = ParquetTarget(name='labels',path=f'v3io:///projects/{project.name}/target.parquet')
labels_set.set_targets([target], with_defaults=False)
labels_set.plot(with_targets=True)

# %% [markdown]
# ### Label set - preview

# %%
fstore.preview(labels_set, transactions_data)
# Out:
#              label               timestamp
# source
# C1022153336      0 2023-06-18 14:47:58.790
# C1006176917      0 2023-06-18 14:48:17.083
# C1010936270      0 2023-06-18 14:48:22.190
# C1033736586      0 2023-06-18 14:48:34.483
# C1019071188      0 2023-06-18 14:49:08.372
# ...            ...                     ...
# C1032715879      0 2023-06-20 14:46:56.703
# C1005806982      0 2023-06-20 14:47:01.067
# C1018783569      0 2023-06-20 14:47:28.450
# C1014847580      0 2023-06-20 14:47:35.432
# C1023803355      0 2023-06-20 14:47:58.790
#
# [10000 rows x 2 columns]

# %% [markdown]
# <br>
#
# ## Step 3: Ingest the features data using batch or real-time
#
# To use the features in training or serving the data must be ingested into the feature store, there are three ways to ingest data:
# 1. Direct ingestion - ingest the data directly from the client/notebook (interactively)
# 2. Batch/scheduled ingestion - create a service/job whithat that ingests data from the source (e.g. file, DB, ..)
# 3. Real-time/Streaming ingestion - create an online service that accepts real-time events (from a stream, http, etc.) and push them into the feature store
#
# Direct and batch ingestion are achieved using the `ingest()` method, while real-time ingestion is done using the `deploy_ingestion_service()` method. Both methods are demonstrated in the following sections. The direct ingestion is great for development and testing while the real-time ingestion is mainly used in production.

# %% [markdown]
# ### Direct/batch ingestion of the sample data
#
# To run training or test the serving you need to ingest and transform the input datasets and store the results in the feature store. The simplest way is to use the `ingest()` method and specify the feature-set and the source (Dataframe, file, etc.).
#
# You can specify the desired target if you want to overwrite the default behavior. For example, set `targets=[ParquetTarget()]` to specify that the data will only be written to parquet files and will not be written to the NoSQL DB (meaning you cannot run real-time serving).
#
# The `ingest()` method has many other args/options, see the documentation for details.

# %%
# Ingest your transactions dataset through your defined pipeline
transactions_df = fstore.ingest(transaction_set, transactions_data, 
                 infer_options=fstore.InferOptions.default())

# Ingestion of your newly created events feature set
events_df = fstore.ingest(user_events_set, user_events_data)

# Ingest the labels feature set
labels_df = fstore.ingest(labels_set, transactions_data)

# %% [markdown]
# ### Deploy a real-time pipeline
#
# When dealing with real-time aggregation, it's important to be able to update these aggregations in real-time.
# For this purpose, you create live serving functions that update the online feature store of the `transactions`
# FeatureSet and `Events` FeatureSet.
#
# Using MLRun's `serving` runtime, create a nuclio function loaded with your feature set's computational graph definition
# and an `HttpSource` to define the HTTP trigger.
#
# Notice that the implementation below does not require any rewrite of the pipeline logic.

# %% [markdown]
# ## 3.1 - Transactions

# %% [markdown]
# ### Transactions - deploy the feature set live endpoint

# %%
# Create iguazio v3io stream and transactions push API endpoint
transaction_stream = f'v3io:///projects/{project.name}/streams/transaction'
transaction_pusher = mlrun.datastore.get_stream_pusher(transaction_stream)

# %%
# Define the source stream trigger (use v3io streams)
# define the `key` and `time` fields (extracted from the Json message).
source = mlrun.datastore.sources.StreamSource(path=transaction_stream , key_field='source', time_field='timestamp')

# Deploy the transactions feature set's ingestion service over a real-time (Nuclio) serverless function
# you can use the run_config parameter to pass function/service specific configuration
transaction_set_endpoint = fstore.deploy_ingestion_service(featureset=transaction_set, source=source)
# Out:
# > 2023-06-20 14:52:54,750 [info] Starting remote function deploy
# 2023-06-20 14:52:55  (info) Deploying function
# 2023-06-20 14:52:55  (info) Building
# 2023-06-20 14:52:55  (info) Staging files and preparing base images
# 2023-06-20 14:52:55  (info) Building processor image
# 2023-06-20 14:54:41  (info) Build complete
# 2023-06-20 14:54:51  (info) Function deploy complete
# > 2023-06-20 14:54:58,031 [info] successfully deployed function: {'internal_invocation_urls': ['nuclio-fraud-demo-admin-transactions-ingest.default-tenant.svc.cluster.local:8080'], 'external_invocation_urls': ['fraud-demo-admin-transactions-ingest-fraud-demo-admin.default-tenant.app.vmdev41.lab.iguazeng.com/']}

# %% [markdown]
# ### Transactions - test the feature set HTTP endpoint

# %% [markdown]
# By defining your `transactions` feature set you can now use MLRun and Storey to deploy it as a live endpoint, ready to ingest new data!
#
# Using MLRun's `serving` runtime, create a nuclio function loaded with your feature set's computational graph definition
# and an `HttpSource` to define the HTTP trigger.

# %%
import requests
import json

# Select a sample from the dataset and serialize it to JSON
transaction_sample = json.loads(transactions_data.sample(1).to_json(orient='records'))[0]
transaction_sample['timestamp'] = str(pd.Timestamp.now())
transaction_sample
# Out:
# {'step': 96,
#  'age': '2',
#  'gender': 'M',
#  'zipcodeOri': 28007,
#  'zipMerchant': 28007,
#  'category': 'es_transportation',
#  'amount': 24.04,
#  'fraud': 0,
#  'timestamp': '2023-06-20 14:54:58.139373',
#  'source': 'C1035666255',
#  'target': 'M1823072687',
#  'device': '6750f74ce7b6401484ca19d14728d636'}

# %%
# Post the sample to the ingestion endpoint
requests.post(transaction_set_endpoint, json=transaction_sample).text
# Out:
# '{"id": "d4a1dc7a-c231-4dac-adac-7bedea42b1b1"}'

# %% [markdown]
# ## 3.2 - User events

# %% [markdown]
# ### User events - deploy the feature set live endpoint
# Deploy the events feature set's ingestion service using the feature set and all the previously defined resources.

# %%
# Create iguazio v3io stream and transactions push API endpoint
events_stream = f'v3io:///projects/{project.name}/streams/events'
events_pusher = mlrun.datastore.get_stream_pusher(events_stream)

# %%
# Define the source stream trigger (use v3io streams)
# define the `key` and `time` fields (extracted from the Json message).
source = mlrun.datastore.sources.StreamSource(path=events_stream , key_field='source', time_field='timestamp')

# Deploy the transactions feature set's ingestion service over a real-time (Nuclio) serverless function
# you can use the run_config parameter to pass function/service specific configuration
events_set_endpoint = fstore.deploy_ingestion_service(featureset=user_events_set, source=source)
# Out:
# > 2023-06-20 14:54:58,357 [info] Starting remote function deploy
# 2023-06-20 14:54:58  (info) Deploying function
# 2023-06-20 14:54:58  (info) Building
# 2023-06-20 14:54:58  (info) Staging files and preparing base images
# 2023-06-20 14:54:58  (info) Building processor image
# 2023-06-20 14:56:44  (info) Build complete
# 2023-06-20 14:56:55  (info) Function deploy complete
# > 2023-06-20 14:57:02,293 [info] successfully deployed function: {'internal_invocation_urls': ['nuclio-fraud-demo-admin-events-ingest.default-tenant.svc.cluster.local:8080'], 'external_invocation_urls': ['fraud-demo-admin-events-ingest-fraud-demo-admin.default-tenant.app.vmdev41.lab.iguazeng.com/']}

# %% [markdown]
# ### User Events - Test the feature set HTTP endpoint

# %%
# Select a sample from the events dataset and serialize it to JSON
user_events_sample = json.loads(user_events_data.sample(1).to_json(orient='records'))[0]
user_events_sample['timestamp'] = str(pd.Timestamp.now())
user_events_sample
# Out:
# {'source': 'C506565122',
#  'event': 'details_change',
#  'timestamp': '2023-06-20 14:57:02.352923'}

# %%
# Post the sample to the ingestion endpoint
requests.post(events_set_endpoint, json=user_events_sample).text
# Out:
# '{"id": "d54a22d2-6a1e-43f0-85dc-5f97b1b59565"}'

# %% [markdown]
# ## Done!
#
# You've completed Part 1 of the data-ingestion with the feature store.
# Proceed to [Part 2](02-create-training-model.html) to learn how to train an ML model using the feature store data.
